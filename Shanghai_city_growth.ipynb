# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
url = "http://www.esa.int/var/esa/storage/images/esa_multimedia/images/2019/06/urban_sprawl_in_shanghai/19436973-1-eng-GB/Urban_sprawl_in_Shanghai.png"
imgraw = plt.imread(url)
plt.imshow(imgraw)
imgraw.shape
# Out:
# (1125, 1500, 4)

# %%
# remove alpha channel
img = imgraw[:,:,0:3]
# obtain palette
palette = img[1040:1040+20,1100:1100+345,:]
plt.imshow(palette)
# remove indicator
img[1000:,1060:,:] = np.array([0,0,0])

# %%
#plt.imshow(np.unique(palette.reshape(-1, palette.shape[2]), axis=0))
plt.imshow(img)
